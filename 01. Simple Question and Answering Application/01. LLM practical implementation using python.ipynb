# %%
# !pip install langchain

# %% [markdown]
# ## Let's use Proprietary LLM from - OpenAI

# %%
# !pip install Openai

# %%
import os
os.environ['OPENAI_API_KEY'] = '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'

# %%
from langchain.llms import OpenAI

# %%
llm = OpenAI(model_name="gpt-3.5-turbo-instruct")
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %%
our_query = "What is the currency of India?"
completion = llm(our_query)  # it is a paid model so will throw an error asking us to pay the bill
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(

# %%
print(completion) # this will print the answer generated by our model
# Out:
# The currency of India is the Indian Rupee (INR).

# %% [markdown]
# ## Let's use open-source LLM hosted on Hugging Face

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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" 
# keep in mind to keep the key same as its used by langchain

# %%
from langchain.llms import HuggingFaceHub

# %%
llm = HuggingFaceHub(repo_id = "google/flan-t5-large")

# %%
# the llm takes a prompt as an input and outputs a completion
our_query = "What is the currency of India?"
completion = llm(our_query)

# %%
print(completion)
# Out:
# rupee
